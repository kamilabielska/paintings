# %%
import pandas as pd
import zipfile
import os
import time
import matplotlib.pyplot as plt
import numpy as np
import pickle
import seaborn as sns
import torch
import copy
import random
import torch.nn as nn
import torch.optim as optim
import shutil

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, ENGLISH_STOP_WORDS as sklear_stopwords
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from nltk.corpus import stopwords

from torch.utils.data import DataLoader, Subset
from torchvision import models, transforms, datasets

from PIL import Image

sns.set_style('whitegrid')
sns.set_context('notebook', font_scale=1.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # data preparation

# %% [markdown]
# - unpack zip folder with the data
# - retrieve labels from filenames and load images
# - correct the invalid character in Albrecht Dürer's surname

# %%
def prepare_data(folder_name, zip_name, size, mode=1, to_pickle=True):
    
    if not os.path.exists(folder_name):
        with zipfile.ZipFile(zip_name, 'r') as archive:
            for file in archive.namelist():
                if file.startswith('resized/') and file != 'resized/':
                    archive.extract(file)
                    
        os.rename('resized', folder_name)
            
    labels, paintings = [], []
    for filename in os.listdir(folder_name):
        path = os.path.join(folder_name, filename)

        if 'Albrecht_D' in filename:
            filename = filename.replace(filename.split('_')[1], 'Durer')
            new_path = os.path.join(folder_name, filename)
            os.rename(path, new_path)
            path = new_path

        labels.append(' '.join(filename.split('_')[:-1]))

        image = cv2.cvtColor(cv2.imread(path, mode), cv2.COLOR_BGR2RGB)
        paintings.append(cv2.resize(image, (size,size)))

    if to_pickle == True:
        with open('paintings', 'wb') as file:
            pickle.dump(paintings, file)
        with open('labels', 'wb') as file:
            pickle.dump(labels, file)
    
    return labels, paintings

# %%
labels, paintings = prepare_data('images', 'resized.zip', size=96)

# %%
paintings, labels = pickle.load(open('paintings','rb')), pickle.load(open('labels','rb'))

# %% [markdown]
# create directory structure required by pytorch

# %%
def train_test_val_folders(folder, all_labels, size=0.1):
    files = os.listdir(folder)
    
    print('splitting...')
    X_train, X_test, y_train, y_test = train_test_split(files, all_labels, stratify=all_labels, test_size=size, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, stratify=y_train, test_size=size, random_state=42)
    
    sets = [X_train, X_val, X_test]
    labels = [y_train, y_val, y_test]
    
    for i, set_name in enumerate(['train', 'val', 'test']):
        
        if not os.path.exists(set_name):
            os.makedirs(set_name)
            
            for j, filename in enumerate(sets[i]):
                inner_folder = os.path.join(set_name, labels[i][j])
                
                if not os.path.exists(inner_folder):
                    os.makedirs(inner_folder)
                    
                path = os.path.join(folder, filename)
                new_path = os.path.join(inner_folder, filename)
                shutil.copyfile(path, new_path)
    
    print('done, files are now in separate folders')

# %%
train_test_val_folders('images', labels)
# Out:
# splitting...
# done, files are now in separate folders

# %% [markdown]
# # eda

# %%
df = pd.read_csv('artists.csv')
df.head()
# Out:
#    id  ... paintings
# 0   0  ...       193
# 1   1  ...        88
# 2   2  ...        70
# 3   3  ...        73
# 4   4  ...       194
#
# [5 rows x 8 columns]

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, y='nationality', palette='husl_d');
plt.title('Number of painters of given nationality', fontsize=16);

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df, x='paintings');
plt.title('Histogram of number of paintings', fontsize=16);

# %%
df[['name','paintings']].sort_values('paintings', ascending=False)[:10]
# Out:
#                      name  paintings
# 8        Vincent van Gogh        877
# 30            Edgar Degas        702
# 13          Pablo Picasso        439
# 15  Pierre-Auguste Renoir        336
# 19         Albrecht Dürer        328
# 46           Paul Gauguin        311
# 16         Francisco Goya        291
# 31              Rembrandt        262
# 20          Alfred Sisley        259
# 32                 Titian        255

# %%
genres = ','.join(list(df['genre'].values)).split(',')

plt.figure(figsize=(8,8))
sns.countplot(y=genres, palette='husl_d');
plt.ylabel('genre');
plt.title('Number of painters representing given genres', fontsize=16);

# %%
#nltk.download('stopwords')
all_sw = list(sklear_stopwords) + stopwords.words('english')
count_vectorizer = CountVectorizer(stop_words = all_sw, max_features=20, ngram_range=(2,2))
fit = count_vectorizer.fit_transform(df['bio'])

counts = pd.DataFrame({'word':count_vectorizer.get_feature_names(), 'count':fit.sum(axis=0).tolist()[0]})
counts = counts.sort_values(by=['count'], ascending=False).reset_index(drop=True)

plt.figure(figsize=(10,7))
sns.barplot(y=counts['word'], x=counts['count'], palette='husl_r_d');
plt.title("Most common bigrams present in painters' bios", fontsize=16);

# %% [markdown]
# some of the paintings

# %%
fig, axes = plt.subplots(2,4, figsize=(14,7))
axes = axes.flatten()
for i in range(8):
    k = random.randint(0, len(paintings))
    axes[i].imshow(paintings[k]);
    axes[i].axis('off');
    axes[i].set_title(labels[k]);

# %%
size = 96

# %%
rgb = np.array(paintings).reshape(-1,size,size,3).reshape(-1, 3)
unique_colours, counts = np.unique(rgb, return_counts=True, axis=0)
colours = pd.DataFrame({'colour':list(unique_colours), 'count':counts}).sort_values('count', ascending=False)

# %% [markdown]
# 400 most/least frequent colors shown on a grid

# %%
most_100 = colours[:400].copy()
least_100 = colours[-400:].copy()

# %%
fig, axes = plt.subplots(1,2, figsize=(12,8))
axes[0].imshow(np.stack(most_100['colour'].values, axis=0).reshape(20,20,3));
axes[1].imshow(np.stack(least_100['colour'].values, axis=0).reshape(20,20,3));
for i in [0,1]:
    axes[i].grid(False);
    axes[i].axis('off');
    which = 'most' if i == 0 else 'least'
    axes[i].set_title(fr'100 {which} frequent colours', fontsize=14)

# %% [markdown]
# this yellow tile in 100 most frequent colours is quite interesting

# %% [markdown]
# # classification

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# get and transform the data and compute class weights

# %%
def pytorch_data_from_folder(path='', batch_size=16, subset=None):
    vecs = ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    
    data_transforms = {
        'train': transforms.Compose([
            transforms.RandomResizedCrop(224),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(*vecs)]),
        'val': transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(*vecs)]),
        'test': transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(*vecs)])
    }
    
    sets = ['train', 'val', 'test']
    image_datasets = {x: datasets.ImageFolder(os.path.join(path,x), data_transforms[x]) for x in sets}
    labels = np.array(image_datasets['train'].targets)
    
    if subset is not None:
        keep = pd.Series(sorted(subset)).map(image_datasets['train'].class_to_idx)
        masks = {x: np.in1d(image_datasets[x].targets, keep) for x in sets}
        mapping = dict(zip(keep, np.arange(0, len(keep))))

        for x in sets:
            image_datasets[x].target_transform = lambda n: mapping[n] if n in list(keep) else len(keep)

        image_datasets = {x: Subset(image_datasets[x], np.where(masks[x] == 1)[0]) for x in sets}
        labels = labels[np.in1d(labels, keep)]
        
    dataloaders = {x: DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=2) for x in sets}
    data_size = {x: len(image_datasets[x]) for x in sets}
    
    weights = compute_class_weight('balanced', classes=sorted(list(set(labels))), y=labels)
    
    return dataloaders, data_size, weights

# %% [markdown]
# define the training loop

# %%
def train_model(model, criterion, optimizer, scheduler, epochs, dataloaders, data_size, es_patience=None):
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0
    epochs_no_improvement = 0

    for epoch in range(epochs):
        print('')
        print(fr'======== Epoch {epoch + 1} / {epochs} ========')
        print('Training...')
        t0 = time.time()

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train() 
            else:
                model.eval()
            
            dataloader = dataloaders[phase]
            running_loss = 0
            running_corrects = 0

            for step, batch in enumerate(dataloader):
                if step % 100 == 0 and not step == 0:
                    print(fr'Batch {step:>5,} of {len(dataloader):>5,}. Elapsed: {(time.time()-t0):.2f} s.')

                inputs = batch[0].to(device)
                labels = batch[1].to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
            
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item()*inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss/data_size[phase]
            epoch_accuracy = running_corrects.double()/data_size[phase]
            
            model.history[phase + '_loss'].append(epoch_loss)
            model.history[phase + '_accuracy'].append(epoch_accuracy)

            print(fr'== {phase} == loss: {epoch_loss:.4f} accuracy: {epoch_accuracy:.4f}')

            if phase == 'val':
                if epoch_accuracy > best_acc:
                    best_acc = epoch_accuracy
                    best_model_wts = copy.deepcopy(model.state_dict())
                    epochs_no_improvement = 0
                else:
                    epochs_no_improvement += 1
        
        if es_patience is not None and epochs_no_improvement >= es_patience:
            print('')
            print(fr'No validation accuracy improvement for {es_patience} consecutive epochs. Stopping training...')
            break
    
    print('')
    print(fr'Training finished. Best validation accuracy: {best_acc:.4f}.')
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# define the test loop

# %%
def test_model(model, dataloaders, data_size):
    model.eval()
    
    dataloader = dataloaders['test']
    pred_labels, test_labels = [], []
    running_corrects = 0
    
    for batch_idx, (inputs, labels) in enumerate(dataloader):
        
        with torch.no_grad():
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

        pred_labels += preds.tolist()
        test_labels += labels.data.tolist()
        running_corrects += torch.sum(preds == labels.data)
        
    accuracy = running_corrects.double()/data_size['test']
    print(fr'test accuracy: {accuracy:.4f}')
    
    return np.array(pred_labels), np.array(test_labels)

# %% [markdown]
# define the model

# %%
class ResModel(nn.Module):
    def __init__(self, nclasses):
        super().__init__()
        self.network = models.resnet50(pretrained=True)
        self.network.fc = nn.Linear(self.network.fc.in_features, nclasses)
        self.history = {'train_loss': [], 'train_accuracy': [],
                        'val_loss': [], 'val_accuracy': []}
        
    def forward(self, x):
        return self.network(x)
    
    def plot_history(self, which='loss'):
        x = np.arange(1, len(self.history['train_loss'])+1)
        plt.figure(figsize=(8,5))
        plt.plot(x, self.history['train_'+which], label='train '+which);
        plt.plot(x, self.history['val_'+which], label='val '+which);
        plt.xlabel('epoch')
        plt.ylabel(which)
        plt.legend();

# %% [markdown]
# ## training with all classes

# %%
dataloaders, data_size, weights = pytorch_data_from_folder(path='/content/drive/My Drive/paintings_data')

# %%
model = ResModel(50).to(device)

criterion = nn.CrossEntropyLoss(weight=torch.tensor(weights).float().to(device))
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %%
best_model = train_model(model, criterion, optimizer, scheduler, 100, dataloaders, data_size, es_patience=3)
# Out:
# ======== Epoch 1 / 100 ========
# Training...
# Batch   100 of   423. Elapsed: 18.37 s.
# Batch   200 of   423. Elapsed: 36.78 s.
# Batch   300 of   423. Elapsed: 54.72 s.
# Batch   400 of   423. Elapsed: 72.49 s.
# == train == loss: 2.8430 accuracy: 0.2660
# == val == loss: 1.7847 accuracy: 0.4761
#
# ======== Epoch 2 / 100 ========
# Training...
# Batch   100 of   423. Elapsed: 18.03 s.
# Batch   200 of   423. Elapsed: 36.18 s.
# Batch   300 of   423. Elapsed: 54.15 s.
# Batch   400 of   423. Elapsed: 72.01 s.
# == train == loss: 1.6909 accuracy: 0.5085
# == val == loss: 1.3532 accuracy: 0.5851
#
# ======== Epoch 3 / 100 ========
# Training...
# Batch   100 of   423. Elapsed: 18.03 s.
# Batch   200 of   423. Elapsed: 36.05 s.
# Batch   300 of   423. Elapsed: 53.97 s.
# Batch   400 of   423. Elapsed: 71.66 s.
# == train == loss: 1.3260 accuracy: 0.5936
# == val == loss: 1.1254 accuracy: 0.6596
#
# ======== Epoch 4 / 100 ========
# Training...
# ...

# %%
model.plot_history('loss')

# %%
model.plot_history('accuracy')

# %%
torch.save(best_model.state_dict(), 'model_resnet50_8178.pth')

# %% [markdown]
# ### prediction

# %% [markdown]
# trying out prediction for a single image

# %%
model = ResModel(50)
model.load_state_dict(torch.load('model_resnet50_8178.pth', map_location=torch.device('cpu')))
model.eval()
# Out:
# ResModel(
#   (network): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
# ...

# %%
test_images, test_labels = [], []
for folder in os.listdir('test'):
    folder_path = os.path.join('test', folder)
    for filename in os.listdir(folder_path):
        test_images.append(os.path.join(folder_path, filename))
        test_labels.append(folder)

# %%
transformation = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
which = random.choice(np.arange(len(test_images)))
with torch.no_grad():
    image_raw = Image.open(test_images[which]).convert('RGB')
    image = transformation(image_raw)
    pred = np.argmax(model(image.view(1, 3, 224, 224)))
    fig, ax = plt.subplots(figsize=(6,6))
    ax.imshow(image_raw);
    ax.axis('off');
    ax.set_title(fr'real: {np.unique(labels)[pred]}, pred: {test_labels[which]}', fontsize=15);

# %% [markdown]
# ## training with 15 most common classes

# %%
df = pd.read_csv('artists.csv')
most_common = df[['name','paintings']].sort_values('paintings', ascending=False)[:15]['name']
most_common = most_common.reset_index(drop=True).str.replace('Dürer', 'Durer')
most_common
# Out:
# 0          Vincent van Gogh
# 1               Edgar Degas
# 2             Pablo Picasso
# 3     Pierre-Auguste Renoir
# 4            Albrecht Durer
# 5              Paul Gauguin
# 6            Francisco Goya
# 7                 Rembrandt
# 8             Alfred Sisley
# 9                    Titian
# 10             Marc Chagall
# 11            Rene Magritte
# 12        Amedeo Modigliani
# 13                Paul Klee
# 14            Henri Matisse
# Name: name, dtype: object

# %%
dataloaders, data_size, weights = pytorch_data_from_folder(path='/content/drive/My Drive/paintings_data',
                                                           subset=most_common)

# %%
model = ResModel(15).to(device)

criterion = nn.CrossEntropyLoss(weight=torch.tensor(weights).float().to(device))
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %%
best_model_15 = train_model(model, criterion, optimizer, scheduler, 100, dataloaders, data_size, es_patience=3)
# Out:
# ======== Epoch 1 / 100 ========
# Training...
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Batch   100 of   256. Elapsed: 302.44 s.
# Batch   200 of   256. Elapsed: 576.25 s.
# == train == loss: 1.4849 accuracy: 0.5010
# == val == loss: 0.6163 accuracy: 0.7834
#
# ======== Epoch 2 / 100 ========
# Training...
# Batch   100 of   256. Elapsed: 19.21 s.
# Batch   200 of   256. Elapsed: 37.40 s.
# == train == loss: 0.7791 accuracy: 0.7205
# == val == loss: 0.4277 accuracy: 0.8293
#
# ======== Epoch 3 / 100 ========
# Training...
# Batch   100 of   256. Elapsed: 18.64 s.
# Batch   200 of   256. Elapsed: 36.71 s.
# ...

# %%
best_model_15.plot_history('loss')

# %%
best_model_15.plot_history('accuracy')

# %%
torch.save(best_model_15.state_dict(), 'model_resnet50_15_9212.pth')

# %% [markdown]
# ## training with 12 classes: well known names

# %%
chosen = ['Salvador Dali', 'Vincent van Gogh', 'Raphael', 'Leonardo da Vinci',
          'Rembrandt', 'Pablo Picasso', 'Francisco Goya', 'Peter Paul Rubens',
          'Claude Monet', 'Edvard Munch', 'Andy Warhol', 'Jackson Pollock']

# %%
dataloaders, data_size, weights = pytorch_data_from_folder(path='/content/drive/My Drive/paintings_data',
                                                           subset=chosen)

# %%
model = ResModel(12).to(device)

criterion = nn.CrossEntropyLoss(weight=torch.tensor(weights).float().to(device))
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %%
best_model_12 = train_model(model, criterion, optimizer, scheduler, 100, dataloaders, data_size, es_patience=3)
# Out:
# ======== Epoch 1 / 100 ========
# Training...
# Batch   100 of   139. Elapsed: 100.41 s.
# == train == loss: 1.5221 accuracy: 0.4413
# == val == loss: 0.8392 accuracy: 0.6506
#
# ======== Epoch 2 / 100 ========
# Training...
# Batch   100 of   139. Elapsed: 18.49 s.
# == train == loss: 0.7728 accuracy: 0.6806
# == val == loss: 0.6661 accuracy: 0.7229
#
# ======== Epoch 3 / 100 ========
# Training...
# Batch   100 of   139. Elapsed: 18.40 s.
# == train == loss: 0.6278 accuracy: 0.7517
# == val == loss: 0.7665 accuracy: 0.8153
#
# ======== Epoch 4 / 100 ========
# Training...
# Batch   100 of   139. Elapsed: 18.25 s.
# == train == loss: 0.5319 accuracy: 0.7841
# == val == loss: 0.4558 accuracy: 0.8434
#
# ======== Epoch 5 / 100 ========
# Training...
# Batch   100 of   139. Elapsed: 18.13 s.
# == train == loss: 0.4183 accuracy: 0.8250
# == val == loss: 0.4867 accuracy: 0.8394
#
# ======== Epoch 6 / 100 ========
# Training...
# Batch   100 of   139. Elapsed: 18.50 s.
# ...

# %%
best_model_12.plot_history('loss')

# %%
best_model_12.plot_history('accuracy')

# %%
torch.save(best_model_12.state_dict(), 'model_resnet50_12_8956.pth')

# %% [markdown]
# ### testing

# %%
model = ResModel(12)
model.load_state_dict(torch.load('model_resnet50_12_8956.pth'));

# %%
pred_labels, test_labels = test_model(model, dataloaders, data_size)
# Out:
# test accuracy: 0.8321

# %%
cm = confusion_matrix(test_labels, pred_labels)

# %%
fig, ax = plt.subplots(figsize=(7,7))
matrix_display = ConfusionMatrixDisplay(cm, display_labels=sorted(chosen))
matrix_display.plot(ax=ax);
plt.delaxes(fig.axes[1])
plt.title('confusion matrix', fontsize=16)
plt.xticks(rotation=90)
ax.grid(False)

# %% [markdown]
# - surprisingly, Picasso's paintings were sometimes taken as van Gogh's paintings
# - there were only two Jackson Pollock's paintings in the test set and both were classified correctly; moreover none of the artists got confused with Pollock
# - Rembrandt's paintings got confused only with Raphael's and Goya's, which are rather reasonable mistakes
# - Andy Warhols's artworks were classified incorrectly only once as Picasso's and one of Picasso's paintings got classified as Warhol's; no other confusion in this case, maybe because Warhol's style is rather distinctive
